# %% [markdown]
# # interesting and useful things you can do for infosec work with Python
#
# ## ***programming not required to get started***
#
# aka: "infosec python ideas" talk

# %% [markdown]
# # What / why
#
# * Automation and empowerment
#   * Computers are machines that run code
#     * Read code to understand what computers do
#     * Write code to *change* what computers do
#   * Do more and better things, reduce drudgery and slogging at $work and in life
#   * Share what you know

# %% [markdown]
# * Python and Infosec
#   * easy to learn (as programming languages go)
#   * "batteries included" and many libraries available
#   * used in many infosec tools by everyone (.* hats)
#     * many great tools written in or extensible in Python

# %% [markdown]
# * this talk
#   * lots of people want to learn more about, start using Python
#     * their goals and interests, skill levels vary
#   * many people struggle with finding an interesting tool or project to practice on
#     * or just a goal to aim at
#   * thus "interesting and useful things you can do for infosec work with Python"
#     * and "programming not required to get started" <= needs more stars
#
# * BETA Talk disclaimer
#   * Feedback appreciated: here, Discord, email, etc

# %% [markdown]
# * me ?
#   * terrible programmer (also bad at college)
#   * security architect somewhere important
#   * community instructor / life-long student
#   * might not be a cat on the keyboard
#
# ![dfirnotes_bare_logo_200.png](attachment:dfirnotes_bare_logo_200.png)
# ```
# BBSTi, CISSP, GIAC -ge 0x10, GSE**2, ITIL, LPI, MAD CTI
# Information Security Educator | Twitter, Github: @dfirnotes
# ```

# %% [markdown]
# ## screenshots
# * as a calculator
#   * ipython or in the notebook
# * support your other studies
#   * ta'Hol scratch code
# * exploit vulnerabilities
#   * 37 vulnerable Python modules in exploit-db this morning: https://www.exploit-db.com/?platform=python
#   * ~4000 sploits and eggs in exploit db with py extension
# * reformat and decode data
#   * unhexlify, codecs etc => Didier Steven's tools: https://github.com/DidierStevens/DidierStevensSuite
#   * check entropy and detect computer-generated data strings: https://github.com/sans-blue-team/freq.py

# %% [markdown]
# * as a calculator
#   * ipython or in the notebook

# %%
# Darn, what's 1000 hex in human numbers again?
0x1000
# Out:
# 4096

# %%
# How many car payments do I have left?
(20000 - (24*450))/450.00
# Out:
# 20.444444444444443

# %% [markdown]
# ![windows-python-as-calculator.png](attachment:windows-python-as-calculator.png)

# %% [markdown]
# * support your other studies
#   * ta'Hol scratch code

# %% [markdown]
# ![vcsode-hol-syllable-scratch.png](attachment:vcsode-hol-syllable-scratch.png)
# _vcsode-hol-syllable-scratch.png: VSCode screeshot of scratch Python code for Klingon language studies_

# %% [markdown]
# * exploit vulnerabilities
#   * 37 vulnerable Python modules in exploit-db this morning: https://www.exploit-db.com/?platform=python
#   * ~4000 sploits and eggs in exploit db with py extension

# %% [markdown]
# ![Screen%20Shot%202022-05-21%20at%2011.03.47%20AM.png](attachment:Screen%20Shot%202022-05-21%20at%2011.03.47%20AM.png)
# _kali-python in exploitdb.png:Kali Linux screenshot of count of Python files in searchsploit, about 4000_

# %% [markdown]
# * reformat and decode data
#   * [binascii](https://docs.python.org/3/library/binascii.html?highlight=binascii),(un)[hexlify](https://docs.python.org/3/library/binascii.html?highlight=hexlify#binascii.unhexlify), [codecs](https://docs.python.org/3/library/codecs.html?highlight=codecs#module-codecs)
#   * Didier Steven's tools: https://github.com/DidierStevens/DidierStevensSuite
#     * pdf-parser.py , oledump.py
#       * many are written in or extensible in Python
#     * TODO ref his conf keynote on scripting for educations
#   * check entropy and detect computer-generated data strings: https://github.com/sans-blue-team/freq.py

# %%
screenshots go here
# Out:
#   File "/tmp/ipykernel_7458/1164072673.py", line 1
#     screenshots go here
#                 ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## demo
# * get a (better) terminal session
#   * ```python3 -c "import pty;pty.spawn('/bin/whoami')"```
# * upload and download files over http and and other means
#   * ```python3 -m http.server``` || ```python2.7 -m SimpleHTTPServer``` || [socket.Socket](https://docs.python.org/3/library/socket.html?highlight=socket#socket.socket)
# * exploit vulnerabilities
#   * ```python -c "print('{}'.format('A' * 1024))"```
# * notebooks: code, results, documentation together
#   * also, slides:
#     * https://towardsdatascience.com/5-slides-for-tips-on-presentation-mode-in-jupyter-notebook-f858b15fff4f?gi=cd220161b46b
#     * https://nbconvert.readthedocs.io/en/latest/usage.html#reveal-js-html-slideshow
# * automate & extend security tools:
#   * Ghidra eg: https://github.com/ghidraninja/ghidra_scripts

# %% [markdown]
# WannaCry sample from https://bazaar.abuse.ch/download/07c44729e2c570b37db695323249474831f5861d45318bf49ccf5d2f5c8ea1cd/
#
# Initial strings analysis turned up some interesting leads, simple Ghidra Python to mark one for followup.
#
# 00431330	%s -m security	"%s -m security"	ds
#
# ```
# interesting_addr= toAddr("00431330")
# listing = currentProgram.getListing()
# codeUnit = listing.getCodeUnitAt(interesting_addr)
# codeUnit.setComment(codeUnit.PRE_COMMENT, "This is an interesting string!")
# ```
#
# ![ghidra-wannacry-comment-string.png](attachment:ghidra-wannacry-comment-string.png)

# %% [markdown]
# ## wave at
# * contribute bugs, code, documentation, and tests to projects
# * upload and download files over http(s) and and other means
#   * http.server, requests
#   * hit an API and get stuff, like from VT: https://developers.virustotal.com/reference/overview
# * Program electronic devices to do your bidding!
#   * Try [CircuitPython](https://learn.adafruit.com/welcome-to-circuitpython/)
# * capture, analyse, and manipulate packets
#   * scapy: https://scapy.readthedocs.io/en/latest/
# * do simple or complex data analysis, and make charts and graphs
#   * Jupyter, Pandas : https://infosecjupyterthon.com/introduction.html

# %% [markdown]
# * automate & extend security tools:
#   * Ghidra eg: https://github.com/ghidraninja/ghidra_scripts
#   * Burp Suite https://portswigger.net/burp/documentation/desktop/tools/extender , ZAP https://github.com/zaproxy/zap-api-python
#   * Metasploit Framework https://github.com/rapid7/metasploit-framework/blob/master/modules/auxiliary/example.py etc.
#   * Empire: https://bc-security.gitbook.io/empire-wiki/module-development/python-modules
# * (advanced) integrate tools and glue systems together
# * (advanced) make entirely new tools

# %% [markdown]
# ## refs / reccs
# * Cool python3 programming tricks:
#   * specialty dictionaries like Counter: https://docs.python.org/3/library/collections.html
# * small projects or use cases to work on
# * books (NoStarch) and courses recommendations (SEC573)

# %% [markdown]
# ## thanks
#
# ## questions
#
# Slides notebook at: https://github.com/DFIRnotes/rules/blob/master/infosec-py.ipynb

# %% [markdown]
# ### linkdump under construction
# http://www.dfirnotes.net/about/
# https://samsclass.info/124/VP2020.htm
# https://infosecjupyterthon.com/introduction.html
# https://scapy.readthedocs.io/en/latest/
# https://github.com/DidierStevens/DidierStevensSuite
# https://www.google.com/search?q=ghidra+plugin+docs&oq=ghidra+plugin+docs&aqs=chrome..69i57j0i546l2.3889j0j7&sourceid=chrome&ie=UTF-8
# https://kalilinuxtutorials.com/kaiju/
# https://github.com/ghidraninja/ghidra_scripts
# https://github.com/rapid7/metasploit-framework
# https://github.com/rapid7/metasploit-framework/blob/master/modules/auxiliary/example.py
# https://docs.python.org/3/library/collections.html
# https://portswigger.net/burp/documentation/desktop/tools/extender
# https://portswigger.net/organizations/security-automation
# https://towardsdatascience.com/5-slides-for-tips-on-presentation-mode-in-jupyter-notebook-f858b15fff4f?gi=cd220161b46b
# https://docs.python.org/3/library/binascii.html?highlight=hexlify#binascii.unhexlify
# https://learn.adafruit.com/welcome-to-circuitpython/what-is-circuitpython?gclid=Cj0KCQjwm6KUBhC3ARIsACIwxBjBMIRVjsFJE4psk6BzZ__cLAzxQ2eWohtAAWBbXMB2xZ8QAM2rpEQaArOmEALw_wcB
# https://bazaar.abuse.ch/download/07c44729e2c570b37db695323249474831f5861d45318bf49ccf5d2f5c8ea1cd/
